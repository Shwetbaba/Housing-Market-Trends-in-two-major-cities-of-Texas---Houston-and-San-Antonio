# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.recenter.tamu.edu/data/housing-activity/#!/activity/MSA/San_Antonio-New_Braunfels'

# %%
response = requests.get(url)

# %%
html_table = df.to_html()
html_table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 html_table = df.to_html()
#       2 html_table
#
# NameError: name 'df' is not defined

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html >
# <html class="ms-isBot" dir="ltr" lang="en-US" ng-app="userInterface">
#  <head>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="Real Estate Center at Texas A&amp;M University, helping Texans make better real estate decisions." name="description"/>
#   <meta content="https://www.recenter.tamu.edu/_catalogs/masterpage/REC/assets/images/rec-og-logo.jpg" property="og:image"/>
#   <meta content="Microsoft SharePoint" name="GENERATOR"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="0" http-equiv="Expires"/>
#   <link href="/_catalogs/masterpage/REC/assets/images/favicon.ico" rel="icon" type="image/png"/>
#   <link href="/_catalogs/masterpage/REC/assets/images/rec-og-logo.jpg" rel="image_src" type="image/jpeg"/>
#   <!--removeIf(local)-->
#   <title>
#    Housing Activity
#
#
#
#
#
#
#
#
#
#
#  -
# ...

# %%
results = soup.find_all('table', class_='caption')
